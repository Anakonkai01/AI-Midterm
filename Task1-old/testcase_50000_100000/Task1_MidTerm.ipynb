# %% [markdown]
# ## Import Required Libraries
#
# - `heapq`: Provides priority queue for A Star Algorithm
# - `queue`: Provides  queue for Breadth-First Search
# - `graphviz`: Used for graph visualization, helpful for visualizing data structures.
# - `uuid`: Generates universally unique identifiers (UUIDs).

# %%
import heapq
import copy
import graphviz as g
import uuid
import random
import queue
import math
from IPython.display import display

# %% [markdown]
# ##**Problem**
# The Problem class represents the task environment for an agent, defining the initial state, goal state(s), and methods to support environment formulation. It includes the following methods:
#
# - **GetInitialState (`self`, `initial_state`)**: The starting state of the problem.
# - **Goal states (`self`, `goal_states`)**: The set of states that satisfy the goal condition.
# - **isGoalState (`self`, `state`)**: Determines whether a given state is a goal state.
# - **getSuccessors (`self`, `state`)**: Returns possible next states from the current state.
# - **getActionCost (`self`, `state`, `action`)**: Returns the cost of taking an action from a state.(For 8-puzzle problem the cost of action is 1)

# %%
class Problem:
    def __init__(self, initial_state, goal_states):
        self.initial_state = initial_state
        self.goal_states = goal_states

    def getInitialState(self):
        return self.initial_state

    def isGoalState(self, state):
        return state in self.goal_states

    def getSuccessors(self, state):
        node = Node(state)
        return node.getSuccessors()

    def getActionCost(self, state, action):
        node = Node.Node(state)
        return node.getActionCost()

    def get_goal_states(self):
        return self.goal_states

    def get_initial_state(self):
        return self.initial_state

# %% [markdown]
# ##**State**
#
# The `State` class represents a board configuration in a tile-based puzzle. It includes the following methods:
# - **GetActions (`self`)**: List of possible actions of the current state.
# - **GetActionCost (`self`, `state`, `action`)**: Get action cost
# - **getSuccessor (`self`, `action`)**: Returns the resulting successor after applying the action
# - **are_adjacent (`getSuccessors`)**, **auto_swap_if_adjacency(`self`)**: Implements logic for swap the tiles if they are in pair (1 and 3 or 2 and 4)

# %%
class State():
    def __init__(self, board):
        self.board = board

    def __eq__(self, other):
        return self.board == other.board

    def __hash__(self):
        return hash(str(self.board))

    def __str__(self):
        return str(self.board)

    def get_board(self):
        return self.board

    def set_board(self, board):
        self.board = board

    def get_blank_position(self):
        for i in range(len(self.get_board())):
            for j in range(len(self.get_board()[0])):
                if self.board[i][j] == 0:
                    return (i, j)

    def swap(self, pos1, pos2):
        i1, j1 = pos1
        i2, j2 = pos2
        self.board[i1][j1], self.board[i2][j2] = self.board[i2][j2], self.board[i1][j1]

    '''Get the possible actions of the current state'''
    def getActions(self):
        actions = []
        blank_position = self.get_blank_position()
        if blank_position[0] > 0:
            actions.append('U')
        if blank_position[0] < len(self.get_board()) - 1:
            actions.append('D')
        if blank_position[1] > 0:
            actions.append('L')
        if blank_position[1] < len(self.get_board()) - 1:
            actions.append('R')
        return actions

    '''Cost of action is 1'''
    def getActionCost(self, state, action):
        return 1

    '''Return successor with action'''
    def getSuccessor(self, action):
        blank_position = self.get_blank_position()
        new_state = copy.deepcopy(self)

        if 'U' == action:
            new_state.swap(blank_position, (blank_position[0] - 1, blank_position[1]))
        elif 'D' == action:
            new_state.swap(blank_position, (blank_position[0] + 1, blank_position[1]))
        elif 'L' == action:
            new_state.swap(blank_position, (blank_position[0], blank_position[1] - 1))
        elif 'R' == action:
            new_state.swap(blank_position, (blank_position[0], blank_position[1] + 1))


        new_state.auto_swap_if_adjacency()
        return new_state


    def are_adjacent(self, pos1, pos2):
        return abs(pos1[0] - pos2[0]) + abs(pos1[1] - pos2[1]) == 1



    def auto_swap_if_adjacency(self):
        '''using dictionary to store position of each number in the board'''
        position = {}
        for i in range(len(self.get_board())):
            for j in range(len(self.get_board()[0])):
                position[self.board[i][j]] = (i, j)

        ''' swap if cell 1 and cell 3 are adjacent'''
        if self.are_adjacent(position[1], position[3]):
            self.swap(position[1], position[3])

        '''swap if cell 2 and cell 4 are adjacent'''
        if self.are_adjacent(position[2], position[4]):
            self.swap(position[2], position[4])

# %% [markdown]
# ## **Node**
#
# The `Node` class represents a state in the search tree. Each node stores information about the state, the action taken to reach it, its parent, and heuristic values used for informed search algorithms like A*.It includes the following methods:
#
# - **__str__(`self`)**: Returns a string representation of the board, including `G` and `H` values.
# - **__lt__(`self`, `other`)**: Compares two nodes based on their `f(x) = G + H` value for A* search.
# - **get_id(`self`)**: Generates a unique ID for visualization based on the state's hash.
# - **getSuccessors(`self`)**: Generates and returns a list of successor nodes by applying all possible actions.
# - **draw(`self`, `dot`, `color='black'`, `drawn_edges=None`)**: Visualizes the node in a graph structure using Graphviz, drawing edges to its `parent`.

# %%
class Node:
    def __init__(self, state, action = None, parent = None, G =None, H=None):
        self.state = state
        self.action = action
        self.parent = parent
        self.G = G
        self.H = H
        self.ID = str(self)

    ''''''
    def __str__(self):
        board_str = '\n'.join(''.join(str(num) if num != 0 else '_' for num in row) for row in self.get_state().get_board())
        return f"{board_str}\n g_value:{self.get_G()}\n h_value: {self.H}"

    def __lt__(self, other):
        """ Compare the f_x for AStar """
        return (self.G + self.H) < (other.G + other.H)
    def get_state(self):
        return self.state

    def get_action(self):
        return self.action

    def get_G(self):
        return self.G

    def set_G(self, G):
        self.G = G

    def get_parent(self):
        return self.parent

    def get_id(self):
        """ Dùng ID cố định dựa trên state để vẽ đồ thị """
        return str(hash(str(self.state)))

    #For visualize the result
    def get_str_node(self):
        return str(self)

    def getActionCost(self):
        return 1

    def set_H(self, H):
        self.H = H

    def get_H(self):
        return self.H

    def set_parent(self, parent):
        self.parent = parent

    #Get all successors of a node
    def getSuccessors(self):
        successors = []
        state_of_node = self.get_state()
        for action in state_of_node.getActions():
            new_state = state_of_node.getSuccessor(action)
            cost = new_state.getActionCost(state_of_node, action)
            successors.append(Node(new_state, action, self, cost))
        return successors


    def draw(self, dot, color='black', drawn_edges=None):
        dot.node(self.get_id(), self.get_str_node(), shape="square", color=color)
        if self.get_parent() is not None:
            dot.edge(self.get_parent().get_id(), self.get_id(), label=self.get_action(), color=color)

# %% [markdown]
# ## Heuristic
#
# - `Num_linear_conflict(current_board, goal_board)`: Counts linear conflicts (tiles blocking each other) in rows and columns.
# - `EnhancedManhattan(state, goalStates)`: Computes Manhattan distance plus a conflict penalty for more accurate heuristics.
# - `getHeuristic(state, goalStates)`: Calls the selected heuristic function (`EnhancedManhattan` or `EnhancedMissplace`).

# %%
# manhattan 
# misplaced
# linear conflict
# linear conflict + manhattan
# linear conflict + misplaced
# pattern database
# ignore_swap_hihi
# bfs

class Heuristic:
    def __init__(self, type):
        self.heuristic_type = type
        self.Heuristics =    {
                                "EnhancedManhattan": self.EnhancedManhattan,
                                "EnhancedMissPlace": self.EnhancedMissplace,
                                "PatternDataBase": self.PatternDataBase,
                             }
        self.heuristic_func = self.Heuristics[self.heuristic_type]
        '''For PaternDatabse Heuristic'''
        self.pdbList = []

    '''Conflict: Number of tile pairs in which one tile prevent other from reaching the goal position'''
    @staticmethod
    def Num_linear_conflict(current_board, goal_board):
        number_of_conflicts = 0

        '''Look-up table for permutation can cause the conflict'''
        look_up_conflict = lambda a,b,c: [[b,a,c], [c,b,a], [a,c,b]]

        ''' Caculate number of confilcts in rows'''
        for row in range(len(current_board)):
            current_row = current_board[row]
            goal_row = goal_board[row]
            a,b,c = goal_row[0], goal_row[1], goal_row[2]
            potential_conflict_rows = look_up_conflict(a,b,c)
            if current_row in potential_conflict_rows:
                if current_row == potential_conflict_rows[1]:
                    number_of_conflicts += 2
                    continue
                number_of_conflicts += 1

        ''' Caculate the number of conflict in columns'''
        for col in range(len(current_board)):
            current_row = [current_board[row][col] for row in range(len(current_board))]
            goal_row= [goal_board[row][col] for row in range(len(goal_board))]
            a,b,c = goal_row[0], goal_row[1], goal_row[2]
            potential_conflict_rows = look_up_conflict(a,b,c)
            if current_row in potential_conflict_rows:
                if current_row == potential_conflict_rows[1]:
                    number_of_conflicts += 2
                    continue
                number_of_conflicts += 1
        return number_of_conflicts

    '''A heuristic that combines the traditional Manhattan distance with the number of conflicts
    (Clarifies cases where two states have the same Manhattan distance but different tile positions in a row or column).'''
    def EnhancedManhattan(self, state, goalStates):
      list_distance = []
      for goal in goalStates:

          board_goal = goal.get_board()
          goal_pos = {board_goal[i][j]: (i, j) for i in range(len(board_goal)) for j in range(len(board_goal))}


          distance = 0
          board_state = state.get_board()
          for i in range(len(board_state)):
              for j in range(len(board_state)):
                  tile = board_state[i][j]
                  if tile != 0:
                      gx, gy = goal_pos[tile]
                      distance += abs(gx - i) + abs(gy - j)


          conflict = Heuristic.Num_linear_conflict(board_state, board_goal)
          list_distance.append(distance + 2 * conflict)
      return min(list_distance)

    @staticmethod
    def EnhancedManhattanWithAGoal( state, goalState):
        # Lấy bảng đích
        board_goal = goalState.get_board()
        goal_pos = {board_goal[i][j]: (i, j) for i in range(len(board_goal)) for j in range(len(board_goal))}

        # Tính Manhattan
        distance = 0
        board_state = state.get_board()
        for i in range(len(board_state)):
            for j in range(len(board_state)):
                tile = board_state[i][j]
                if tile != 0:
                    gx, gy = goal_pos[tile]
                    distance += abs(gx - i) + abs(gy - j)

        # Tính số conflict với goal hiện tại
        conflict = Heuristic.Num_linear_conflict(board_state, board_goal)

        # Trả về tổng Manhattan và conflict
        return distance + 2 * conflict

    def EnhancedMissplace(self, state, goalStates):
        min_misplaced = 9
        for goalState in goalStates:
            misplaced = 0
            board_state = state.get_board()
            board_goal = goalState.get_board()


            for i in range(len(board_state)):
                for j in range(len(board_state)):
                    if board_state[i][j] != board_goal[i][j]:
                        misplaced += 1


            conflict = Heuristic.Num_linear_conflict(board_state, board_goal)
            min_misplaced = min(min_misplaced, misplaced + 2 * conflict)

        return min_misplaced





# Procedure BUILD_FOUR_PDBS(goals[4]):
#     pdb_list ← ∅
#     For each goal g in goals:
#         pdb_g ← BUILD_PDB_FROM_GOAL(g)      // BFS để xây PDB cho goal g
#         pdb_list.add(pdb_g)
#     return pdb_list

# Procedure BUILD_PDB_FROM_GOAL(goal):
#     Initialize an empty map pdb           // pdb[state] = cost ngắn nhất từ state đến goal
#     Create a queue Q
#     pdb[goal] ← 0
#     Enqueue(goal, Q)
#     while Q is not empty:
#         current ← Dequeue(Q)
#         current_cost ← pdb[current]
#         successors ← GET_SUCCESSORS(current)  // sinh tất cả successor (có auto swap)
#         for each (succ, stepCost) in successors:
#             if succ not in pdb:
#                 pdb[succ] ← current_cost + stepCost
#                 Enqueue(succ, Q)
#     return pdb

    def PatternDataBase(self, state, goalStates):
        """
        Hàm được gọi mỗi lần cần tính heuristic PDB cho 'state'.
        Ta đã có self.pdbList = [pdb_goal1, pdb_goal2, pdb_goal3, pdb_goal4]
        Mỗi pdb_goalX là dict: { state_tupla -> cost }.

        => Tính cost = min( pdb_goalX.get(state_tupla, infinity) )
        """
        if not self.pdbList:
            # Nếu chưa build, trả về 0 hoặc Infinity tuỳ
            return 0
        state_key = tuple(num for row in state.get_board() for num in row)
        best_cost = math.inf
        for pdb_dict in self.pdbList:
            cost = pdb_dict.get(state_key, math.inf)
            if cost < best_cost:
                best_cost = cost
        return best_cost

    def PatternDataBaseBuildAll(self, goalStates):
        """
        Xây 4 PDB, mỗi PDB_i ứng với goalStates[i].
        Trả về list 4 dict.
        """
        pdb_list = []
        for goal in goalStates:
            pdb_g = self.buildPDBFromGoal(goal)
            pdb_list.append(pdb_g)
        return pdb_list

    def buildPDBFromGoal(self, goal):
        """
        BFS từ goal, duyệt toàn bộ state reachable (theo quy tắc di chuyển + auto swap),
        ghi pdb[state_tuple] = cost từ state -> goal.
        """
        pdb = {}
        Q = queue.Queue()

        # Chuyển goal thành key (tuple)
        goal_key = tuple(num for row in goal.get_board() for num in row)

        pdb[goal_key] = 0
        Q.put(goal)

        while not Q.empty():
            current_state = Q.get()
            current_cost_key = tuple(num for row in current_state.get_board() for num in row)
            current_cost = pdb[current_cost_key]

            current_node = Node(current_state)
            for successor in current_node.getSuccessors():
                succ_key = tuple(num for row in successor.get_state().get_board() for num in row)
                if succ_key not in pdb:
                    pdb[succ_key] = current_cost + successor.getActionCost()
                    Q.put(successor.get_state())

        return pdb
    def getHeuristic(self, state, goalStates):
        return self.heuristic_func(state, goalStates)

# %%
goal_states = []
# goal_states.append(State([[1, 2, 3], [4, 5, 6], [7, 8, 0]]))

# goal_states.append(State([[8, 7, 6], [5, 4, 3], [2, 1, 0]]))

# goal_states.append(State([[0, 1, 2], [3, 4, 5], [6, 7, 8]]))

# goal_states.append(State([[0, 8, 7], [6, 5, 4], [3, 2, 1]]))

# Giả sử bạn đã có H.pdbList (4 dict PDB)
H = Heuristic(type="PatternDataBase")  # Or any code that fills H.pdbList
n = H.PatternDataBaseBuildAll(goal_states)

# %%
import pickle
import os

# Đường dẫn thư mục trên máy tính nơi bạn muốn lưu file
# Ví dụ: Lưu trong thư mục "MyPDB" nằm cùng với file Python của bạn
save_dir = './MyPDB/'

# Tạo thư mục nếu chưa tồn tại
os.makedirs(save_dir, exist_ok=True)

# Giả sử H.pdbList đã được khởi tạo và chứa dữ liệu cần lưu
i = 1
for goal_pdb in n:
    
    filename = f'DatabaseForGoal{i}.pkl'
    fullpath = os.path.join(save_dir, filename)  # Nối đường dẫn đầy đủ

    with open(fullpath, 'wb') as f:
        pickle.dump(goal_pdb, f)

    print(f"Saved file: {fullpath}")
    i += 1

# %%
# import os
# import pickle

# # Đường dẫn chứa các file pickle
# save_dir = './MyPDB/'  # Đường dẫn tới thư mục chứa các file pickle đã lưu

# # Tạo dictionary để chứa dữ liệu load được
# loaded_data = []

# # Giả sử tên file là DatabaseForGoal1.pkl, DatabaseForGoal2.pkl, DatabaseForGoal3.pkl, DatabaseForGoal4.pkl
# for i in range(1, 5):
#     filename = f'DatabaseForGoal{i}.pkl'
#     fullpath = os.path.join(save_dir, filename)
    
#     # Mở file ở chế độ đọc nhị phân và load dữ liệu
#     with open(fullpath, 'rb') as f:
#         data = pickle.load(f)
#         # Lưu vào dictionary với key tùy chọn, ví dụ: 'goal_1', 'goal_2', ...
#         loaded_data.append(data)
        
#     print(f"Loaded file: {fullpath}")

# # In ra nội dung của dictionary chứa dữ liệu đã load
# print("All data loaded:")
# print(loaded_data)

# %%
class Search:
    def __init__(self,heuristic: Heuristic, numberNodesDraw = None):
        self.heuristic = heuristic
        self.graph = None
        self.numberNodesDraw = numberNodesDraw if numberNodesDraw is not None else 0
        self.uniqueId = str(uuid.uuid4())[:8] #Id for visual graph

    '''Graph Search AStar Algorithm '''
    def AStar(self, problem):
        if self.numberNodesDraw:
            self.graph = self.graph = g.Digraph(name=f"Graph_{self.uniqueId}")
        expandedNodes = 0

        initial_state = problem.get_initial_state()
        if problem.isGoalState(initial_state):
            return [], expandedNodes

        initial_H  = self.heuristic.heuristic_func(initial_state, problem.get_goal_states())
        initial_node = Node(initial_state, H= initial_H, G = 0)

        frontier = []
        heapq.heappush(frontier, (0, initial_node))

        costSoFar = {initial_node.get_state() : 0}
        #explored = set()  (ko caanf thiet )

        while frontier:
            g_value, node = heapq.heappop(frontier)
            expandedNodes += 1


            '''Only draw nodes up to the allowed limit; the algorithm still runs normally.'''
            if self.numberNodesDraw is not None and expandedNodes <= self.numberNodesDraw:
                node.draw(self.graph)

            if problem.isGoalState(node.get_state()):
                return self.getPath(node), expandedNodes

            for successor in node.getSuccessors():
                stateOfSuccessor = successor.get_state()
                g_value = node.get_G() + successor.getActionCost()
                h_value = self.heuristic.heuristic_func(stateOfSuccessor, problem.get_goal_states())


                '''No need to compute f(x) = g(x) + h(x) explicitly as __lt__ is defined in Node.'''
                if stateOfSuccessor not in costSoFar or g_value < costSoFar[stateOfSuccessor]:
                    costSoFar[stateOfSuccessor] = g_value
                    successor.set_G(g_value)
                    successor.set_H(h_value)
                    successor.set_parent(node)
                    heapq.heappush(frontier, (g_value, successor))

        return None, None


    def getPath(self, node):
        path = []
        while node:
            path.append(node)
            if isinstance(node, Node):
                node = node.get_parent()
        return path[::-1]

    '''Visualize the AStar Algorithm'''
    def Visual(self, numberNodesDraw, problem):
        self.numberNodesDraw = numberNodesDraw
        path_nodes,_ = self.AStar(problem)
        display(g.Source(self.graph.source))

# %%
class BFS():
  def BFS(self, problem: Problem):
      expandedNodes = 0
      initial_state = problem.get_initial_state()
      if problem.isGoalState(initial_state):
          return [], expandedNodes

      initial_node = Node(initial_state, G=0)
      frontier = []
      frontier.append(initial_node)
      explored = set()

      while frontier:
          node = frontier.pop(0)
          expandedNodes += 1

          if problem.isGoalState(node.get_state()):
              return self.getPath(node), expandedNodes

          for successor in node.getSuccessors():
              stateOfSuccessor = successor.get_state()
              if stateOfSuccessor not in explored:
                  explored.add(stateOfSuccessor)
                  successor.set_parent(node)
                  frontier.append(successor)
      return None

  def getPath(self, node):
    path = []
    while node:
        path.append(node)
        if isinstance(node, Node):
            node = node.get_parent()
    return path[::-1]

# %%
# run bfs and store the list of action and total cost in a file and expanded node
# store the initial state and goal state in the file

def run_bfs(problem, initial_state, testcase_number=1):
    bfs = BFS()
    path, expanded_nodes = bfs.BFS(problem)
    if path is None:
        print("No solution found.")
        return

    # Lấy danh sách các hành động (loại bỏ node đầu tiên không có hành động)
    actions = [node.get_action() for node in path if node.get_action() is not None]
    # Lấy trạng thái cuối cùng
    
    if problem.isGoalState(initial_state):
        final_state = initial_state.get_board()
    else:
        final_state = path[-1].get_state().get_board()
    
    # Mở file ở chế độ append để ghi thêm kết quả của testcase mới
    save_path = "bfs_result.txt"
    os.makedirs(os.path.dirname(save_path) or ".", exist_ok=True)

    with open(save_path, "a") as f:
        f.write(f"Testcase: {testcase_number}\n")
        f.write(f"Initial State: {initial_state.get_board()}\n")
        f.write(f"Goal State: {final_state}\n")
        f.write(f"Total Cost: {len(path) - 1}\n")
        f.write(f"Expanded Nodes: {expanded_nodes}\n")
        f.write("Actions: ")
        for action in actions:
            f.write(f"{action} -> ")
        f.write("Goal Reached\n")
        f.write("----------------------------------------------------\n\n")

    print(f"testcase number {testcase_number}")

# %%
def load_all_states(file_path):
    with open(file_path, 'rb') as f:
        states = pickle.load(f)
    return states

# Kiểm tra: Load lại các trạng thái đã lưu và in ra số lượng cũng như 5 trạng thái đầu tiên
loaded_states = load_all_states('./all_states_8_puzzles.pkl')

# %%
# 
goal_states = []
goal_states.append(State([[1, 2, 3], [4, 5, 6], [7, 8, 0]]))
goal_states.append(State([[8, 7, 6], [5, 4, 3], [2, 1, 0]]))
goal_states.append(State([[0, 1, 2], [3, 4, 5], [6, 7, 8]]))
goal_states.append(State([[0, 8, 7], [6, 5, 4], [3, 2, 1]]))

numberLoadState = len(loaded_states)

for i in range(50000,100001):
    initial_state = State(loaded_states[i])
    problem = Problem(initial_state, goal_states)
    run_bfs(problem, initial_state, i)
# Out:
# testcase number 50000
# testcase number 50001
# testcase number 50002
# testcase number 50003
# testcase number 50004
# testcase number 50005
# testcase number 50006
# testcase number 50007
# testcase number 50008
# testcase number 50009
# testcase number 50010
# testcase number 50011
# testcase number 50012
# testcase number 50013
# testcase number 50014
# testcase number 50015
# testcase number 50016
# testcase number 50017
# testcase number 50018
# testcase number 50019
# testcase number 50020
# testcase number 50021
# testcase number 50022
# testcase number 50023
# testcase number 50024
# testcase number 50025
# testcase number 50026
# testcase number 50027
# testcase number 50028
# testcase number 50029
# testcase number 50030
# testcase number 50031
# testcase number 50032
# testcase number 50033
# testcase number 50034
# testcase number 50035
# testcase number 50036
# testcase number 50037
# testcase number 50038
# testcase number 50039
# testcase number 50040
# testcase number 50041
# testcase number 50042
# testcase number 50043
# testcase number 50044
# testcase number 50045
# testcase number 50046
# testcase number 50047
# testcase number 50048
# testcase number 50049
# testcase number 50050
# testcase number 50051
# testcase number 50052
# testcase number 50053
# testcase number 50054
# testcase number 50055
# testcase number 50056
# testcase number 50057
# testcase number 50058
# testcase number 50059
# testcase number 50060
# testcase number 50061
# testcase number 50062
# testcase number 50063
# testcase number 50064
# testcase number 50065
# testcase number 50066
# testcase number 50067
# testcase number 50068
# testcase number 50069
# testcase number 50070
# testcase number 50071
# testcase number 50072
# testcase number 50073
# testcase number 50074
# testcase number 50075
# testcase number 50076
# testcase number 50077
# testcase number 50078
# testcase number 50079
# testcase number 50080
# testcase number 50081
# testcase number 50082
# testcase number 50083
# testcase number 50084
# testcase number 50085
# testcase number 50086
# testcase number 50087
# testcase number 50088
# testcase number 50089
# testcase number 50090
# testcase number 50091
# testcase number 50092
# testcase number 50093
# testcase number 50094
# testcase number 50095
# testcase number 50096
# testcase number 50097
# testcase number 50098
# testcase number 50099
# testcase number 50100
# testcase number 50101
# testcase number 50102
# testcase number 50103
# testcase number 50104
# testcase number 50105
# testcase number 50106
# testcase number 50107
# testcase number 50108
# testcase number 50109
# testcase number 50110
# testcase number 50111
# testcase number 50112
# testcase number 50113
# testcase number 50114
# testcase number 50115
# testcase number 50116
# testcase number 50117
# testcase number 50118
# testcase number 50119
# testcase number 50120
# testcase number 50121
# testcase number 50122
# testcase number 50123
# testcase number 50124
# testcase number 50125
# testcase number 50126
# testcase number 50127
# testcase number 50128
# testcase number 50129
# testcase number 50130
# testcase number 50131
# testcase number 50132
# testcase number 50133
# testcase number 50134
# testcase number 50135
# testcase number 50136
# testcase number 50137
# testcase number 50138
# testcase number 50139
# testcase number 50140
# testcase number 50141
# testcase number 50142
# testcase number 50143
# testcase number 50144
# testcase number 50145
# testcase number 50146
# testcase number 50147
# testcase number 50148
# testcase number 50149
# testcase number 50150
# testcase number 50151
# testcase number 50152
# testcase number 50153
# testcase number 50154
# testcase number 50155
# testcase number 50156
# testcase number 50157
# testcase number 50158
# testcase number 50159
# testcase number 50160
# testcase number 50161
# testcase number 50162
# testcase number 50163
# testcase number 50164
# testcase number 50165
# testcase number 50166
# testcase number 50167
# testcase number 50168
# testcase number 50169
# testcase number 50170
# testcase number 50171
# testcase number 50172
# testcase number 50173
# testcase number 50174
# testcase number 50175
# testcase number 50176
# testcase number 50177
# testcase number 50178
# testcase number 50179
# testcase number 50180
# testcase number 50181
# testcase number 50182
# testcase number 50183
# testcase number 50184
# testcase number 50185
# testcase number 50186
# testcase number 50187
# testcase number 50188
# testcase number 50189
# testcase number 50190
# testcase number 50191
# testcase number 50192
# testcase number 50193
# testcase number 50194
# testcase number 50195
# testcase number 50196
# testcase number 50197
# testcase number 50198
# testcase number 50199
# testcase number 50200
# testcase number 50201
# testcase number 50202
# testcase number 50203
# testcase number 50204
# testcase number 50205
# testcase number 50206
# testcase number 50207
# testcase number 50208
# testcase number 50209
# testcase number 50210
# testcase number 50211
# testcase number 50212
# testcase number 50213
# testcase number 50214
# testcase number 50215
# testcase number 50216
# testcase number 50217
# testcase number 50218
# testcase number 50219
# testcase number 50220
# testcase number 50221
# testcase number 50222
# testcase number 50223
# testcase number 50224
# testcase number 50225
# testcase number 50226
# testcase number 50227
# testcase number 50228
# testcase number 50229
# testcase number 50230
# testcase number 50231
# testcase number 50232
# testcase number 50233
# testcase number 50234
# testcase number 50235
# testcase number 50236
# testcase number 50237
# testcase number 50238
# testcase number 50239
# testcase number 50240
# testcase number 50241
# testcase number 50242
# testcase number 50243
# testcase number 50244
# testcase number 50245
# testcase number 50246
# testcase number 50247
# testcase number 50248
# testcase number 50249
# testcase number 50250
# testcase number 50251
# testcase number 50252
# testcase number 50253
# testcase number 50254
# testcase number 50255
# testcase number 50256
# testcase number 50257
# testcase number 50258
# testcase number 50259
# testcase number 50260
# testcase number 50261
# testcase number 50262
# testcase number 50263
# testcase number 50264
# testcase number 50265
# testcase number 50266
# testcase number 50267
# testcase number 50268
# testcase number 50269
# testcase number 50270
# testcase number 50271
# testcase number 50272
# testcase number 50273
# testcase number 50274
# testcase number 50275
# testcase number 50276
# testcase number 50277
# testcase number 50278
# testcase number 50279
# testcase number 50280
# testcase number 50281
# testcase number 50282
# testcase number 50283
# testcase number 50284
# testcase number 50285
# testcase number 50286
# testcase number 50287
# testcase number 50288
# testcase number 50289
# testcase number 50290
# testcase number 50291
# testcase number 50292
# testcase number 50293
# testcase number 50294
# testcase number 50295
# testcase number 50296
# testcase number 50297
# testcase number 50298
# testcase number 50299
# testcase number 50300
# testcase number 50301
# testcase number 50302
# testcase number 50303
# testcase number 50304
# testcase number 50305
# testcase number 50306
# testcase number 50307
# testcase number 50308
# testcase number 50309
# testcase number 50310
# testcase number 50311
# testcase number 50312
# testcase number 50313
# testcase number 50314
# testcase number 50315
# testcase number 50316
# testcase number 50317
# testcase number 50318
# testcase number 50319
# testcase number 50320
# testcase number 50321
# testcase number 50322
# testcase number 50323
# testcase number 50324
# testcase number 50325
# testcase number 50326
# testcase number 50327
# testcase number 50328
# testcase number 50329
# testcase number 50330
# testcase number 50331
# testcase number 50332
# testcase number 50333
# testcase number 50334
# testcase number 50335
# testcase number 50336
# testcase number 50337
# testcase number 50338
# testcase number 50339
# testcase number 50340
# testcase number 50341
# testcase number 50342
# testcase number 50343
# testcase number 50344
# testcase number 50345
# testcase number 50346
# testcase number 50347
# testcase number 50348
# testcase number 50349
# testcase number 50350
# testcase number 50351
# testcase number 50352
# testcase number 50353
# testcase number 50354
# testcase number 50355
# testcase number 50356
# testcase number 50357
# testcase number 50358
# testcase number 50359
# testcase number 50360
# testcase number 50361
# testcase number 50362
# testcase number 50363
# testcase number 50364
# testcase number 50365
# testcase number 50366
# testcase number 50367
# testcase number 50368
# testcase number 50369
# testcase number 50370
# testcase number 50371
# testcase number 50372
# testcase number 50373
# testcase number 50374
# testcase number 50375
# testcase number 50376
# testcase number 50377
# testcase number 50378
# testcase number 50379
# testcase number 50380
# testcase number 50381
# testcase number 50382
# testcase number 50383
# testcase number 50384
# testcase number 50385
# testcase number 50386
# testcase number 50387
# testcase number 50388
# testcase number 50389
# testcase number 50390
# testcase number 50391
# testcase number 50392
# testcase number 50393
# testcase number 50394
# testcase number 50395
# testcase number 50396
# testcase number 50397
# testcase number 50398
# testcase number 50399
# testcase number 50400
# testcase number 50401
# testcase number 50402
# testcase number 50403
# testcase number 50404
# testcase number 50405
# testcase number 50406
# testcase number 50407
# testcase number 50408
# testcase number 50409
# testcase number 50410
# testcase number 50411
# testcase number 50412
# testcase number 50413
# testcase number 50414
# testcase number 50415
# testcase number 50416
# testcase number 50417
# testcase number 50418
# testcase number 50419
# testcase number 50420
# testcase number 50421
# testcase number 50422
# testcase number 50423
# testcase number 50424
# testcase number 50425
# testcase number 50426
# testcase number 50427
# testcase number 50428
# testcase number 50429
# testcase number 50430
# testcase number 50431
# testcase number 50432
# testcase number 50433
# testcase number 50434
# testcase number 50435
# testcase number 50436
# testcase number 50437
# testcase number 50438
# testcase number 50439
# testcase number 50440
# testcase number 50441
# testcase number 50442
# testcase number 50443
# testcase number 50444
# testcase number 50445
# testcase number 50446
# testcase number 50447
# testcase number 50448
# testcase number 50449
# testcase number 50450
# testcase number 50451
# testcase number 50452
# testcase number 50453
# testcase number 50454
# testcase number 50455
# testcase number 50456
# testcase number 50457
# testcase number 50458
# testcase number 50459
# testcase number 50460
# testcase number 50461
# testcase number 50462
# testcase number 50463
# testcase number 50464
# testcase number 50465
# testcase number 50466
# testcase number 50467
# testcase number 50468
# testcase number 50469
# testcase number 50470
# testcase number 50471
# testcase number 50472
# testcase number 50473
# testcase number 50474
# testcase number 50475
# testcase number 50476
# testcase number 50477
# testcase number 50478
# testcase number 50479
# testcase number 50480
# testcase number 50481
# testcase number 50482
# testcase number 50483
# testcase number 50484
# testcase number 50485
# testcase number 50486
# testcase number 50487
# testcase number 50488
# testcase number 50489
# testcase number 50490
# testcase number 50491
# testcase number 50492
# testcase number 50493
# testcase number 50494
# testcase number 50495
# testcase number 50496
# testcase number 50497
# testcase number 50498
# testcase number 50499
# testcase number 50500
# testcase number 50501
# testcase number 50502
# testcase number 50503
# testcase number 50504
# testcase number 50505
# testcase number 50506
# testcase number 50507
# testcase number 50508
# testcase number 50509
# testcase number 50510
# testcase number 50511
# testcase number 50512
# testcase number 50513
# testcase number 50514
# testcase number 50515
# testcase number 50516
# testcase number 50517
# testcase number 50518
# testcase number 50519
# testcase number 50520
# testcase number 50521
# testcase number 50522
# testcase number 50523
# testcase number 50524
# testcase number 50525
# testcase number 50526
# testcase number 50527
# testcase number 50528
# testcase number 50529
# testcase number 50530
# testcase number 50531
# testcase number 50532
# testcase number 50533
# testcase number 50534
# testcase number 50535
# testcase number 50536
# testcase number 50537
# testcase number 50538
# testcase number 50539
# testcase number 50540
# testcase number 50541
# testcase number 50542
# testcase number 50543
# testcase number 50544
# testcase number 50545
# testcase number 50546
# testcase number 50547
# testcase number 50548
# testcase number 50549
# testcase number 50550
# testcase number 50551
# testcase number 50552
# testcase number 50553
# testcase number 50554
# testcase number 50555
# testcase number 50556
# testcase number 50557
# testcase number 50558
# testcase number 50559
# testcase number 50560
# testcase number 50561
# testcase number 50562
# testcase number 50563
# testcase number 50564
# testcase number 50565
# testcase number 50566
# testcase number 50567
# testcase number 50568
# testcase number 50569
# testcase number 50570
# testcase number 50571
# testcase number 50572
# testcase number 50573
# testcase number 50574
# testcase number 50575
# testcase number 50576
# testcase number 50577
# testcase number 50578
# testcase number 50579
# testcase number 50580
# testcase number 50581
# testcase number 50582
# testcase number 50583
# testcase number 50584
# testcase number 50585
# testcase number 50586
# testcase number 50587
# testcase number 50588
# testcase number 50589
# testcase number 50590
# testcase number 50591
# testcase number 50592
# testcase number 50593
# testcase number 50594
# testcase number 50595
# testcase number 50596
# testcase number 50597
# testcase number 50598
# testcase number 50599
# testcase number 50600
# testcase number 50601
# testcase number 50602
# testcase number 50603
# testcase number 50604
# testcase number 50605
# testcase number 50606
# testcase number 50607
# testcase number 50608
# testcase number 50609
# testcase number 50610
# testcase number 50611
# testcase number 50612
# testcase number 50613
# testcase number 50614
# testcase number 50615
# testcase number 50616
# testcase number 50617
# testcase number 50618
# testcase number 50619
# testcase number 50620
# testcase number 50621
# testcase number 50622
# testcase number 50623
# testcase number 50624
# testcase number 50625
# testcase number 50626
# testcase number 50627
# testcase number 50628
# testcase number 50629
# testcase number 50630
# testcase number 50631
# testcase number 50632
# testcase number 50633
# testcase number 50634
# testcase number 50635
# testcase number 50636
# testcase number 50637
# testcase number 50638
# testcase number 50639
# testcase number 50640
# testcase number 50641
# testcase number 50642
# testcase number 50643
# testcase number 50644
# testcase number 50645
# testcase number 50646
# testcase number 50647
# testcase number 50648
# testcase number 50649
# testcase number 50650
# testcase number 50651
# testcase number 50652
# testcase number 50653
# testcase number 50654
# testcase number 50655
# testcase number 50656
# testcase number 50657
# testcase number 50658
# testcase number 50659
# testcase number 50660
# testcase number 50661
# testcase number 50662
# testcase number 50663
# testcase number 50664
# testcase number 50665
# testcase number 50666
# testcase number 50667
# testcase number 50668
# testcase number 50669
# testcase number 50670
# testcase number 50671
# testcase number 50672
# testcase number 50673
# testcase number 50674
# testcase number 50675
# testcase number 50676
# testcase number 50677
# testcase number 50678
# testcase number 50679
# testcase number 50680
# testcase number 50681
# testcase number 50682
# testcase number 50683
# testcase number 50684
# testcase number 50685
# testcase number 50686
# testcase number 50687
# testcase number 50688
# testcase number 50689
# testcase number 50690
# testcase number 50691
# testcase number 50692
# testcase number 50693
# testcase number 50694
# testcase number 50695
# testcase number 50696
# testcase number 50697
# testcase number 50698
# testcase number 50699
# testcase number 50700
# testcase number 50701
# testcase number 50702
# testcase number 50703
# testcase number 50704
# testcase number 50705
# testcase number 50706
# testcase number 50707
# testcase number 50708
# testcase number 50709
# testcase number 50710
# testcase number 50711
# testcase number 50712
# testcase number 50713
# testcase number 50714
# testcase number 50715
# testcase number 50716
# testcase number 50717
# testcase number 50718
# testcase number 50719
# testcase number 50720
# testcase number 50721
# testcase number 50722
# testcase number 50723
# testcase number 50724
# testcase number 50725
# testcase number 50726
# testcase number 50727
# testcase number 50728
# testcase number 50729
# testcase number 50730
# testcase number 50731
# testcase number 50732
# testcase number 50733
# testcase number 50734
# testcase number 50735
# testcase number 50736
# testcase number 50737
# testcase number 50738
# testcase number 50739
# testcase number 50740
# testcase number 50741
# testcase number 50742
# testcase number 50743
# testcase number 50744
# testcase number 50745
# testcase number 50746
# testcase number 50747
# testcase number 50748
# testcase number 50749
# testcase number 50750
# testcase number 50751
# testcase number 50752
# testcase number 50753
# testcase number 50754
# testcase number 50755
# testcase number 50756
# testcase number 50757
# testcase number 50758
# testcase number 50759
# testcase number 50760
# testcase number 50761
# testcase number 50762
# testcase number 50763
# testcase number 50764
# testcase number 50765
# testcase number 50766
# testcase number 50767
# testcase number 50768
# testcase number 50769
# testcase number 50770
# testcase number 50771
# testcase number 50772
# testcase number 50773
# testcase number 50774
# testcase number 50775
# testcase number 50776
# testcase number 50777
# testcase number 50778
# testcase number 50779
# testcase number 50780
# testcase number 50781
# testcase number 50782
# testcase number 50783
# testcase number 50784
# testcase number 50785
# testcase number 50786
# testcase number 50787
# testcase number 50788
# testcase number 50789
# testcase number 50790
# testcase number 50791
# testcase number 50792
# testcase number 50793
# testcase number 50794
# testcase number 50795
# testcase number 50796
# testcase number 50797
# testcase number 50798
# testcase number 50799
# testcase number 50800
# testcase number 50801
# testcase number 50802
# testcase number 50803
# testcase number 50804
# testcase number 50805
# testcase number 50806
# testcase number 50807
# testcase number 50808
# testcase number 50809
# testcase number 50810
# testcase number 50811
# testcase number 50812
# testcase number 50813
# testcase number 50814
# testcase number 50815
# testcase number 50816
# testcase number 50817
# testcase number 50818
# testcase number 50819
# testcase number 50820
# testcase number 50821
# testcase number 50822
# testcase number 50823
# testcase number 50824
# testcase number 50825
# testcase number 50826
# testcase number 50827
# testcase number 50828
# testcase number 50829
# testcase number 50830
# testcase number 50831
# testcase number 50832
# testcase number 50833
# testcase number 50834
# testcase number 50835
# testcase number 50836
# testcase number 50837
# testcase number 50838
# testcase number 50839
# testcase number 50840
# testcase number 50841
# testcase number 50842
# testcase number 50843
# testcase number 50844
# testcase number 50845
# testcase number 50846
# testcase number 50847
# testcase number 50848
# testcase number 50849
# testcase number 50850
# testcase number 50851
# testcase number 50852
# testcase number 50853
# testcase number 50854
# testcase number 50855
# testcase number 50856
# testcase number 50857
# testcase number 50858
# testcase number 50859
# testcase number 50860
# testcase number 50861
# testcase number 50862
# testcase number 50863
# testcase number 50864
# testcase number 50865
# testcase number 50866
# testcase number 50867
# testcase number 50868
# testcase number 50869
# testcase number 50870
# testcase number 50871
# testcase number 50872
# testcase number 50873
# testcase number 50874
# testcase number 50875
# testcase number 50876
# testcase number 50877
# testcase number 50878
# testcase number 50879
# testcase number 50880
# testcase number 50881
# testcase number 50882
# testcase number 50883
# testcase number 50884
# testcase number 50885
# testcase number 50886
# testcase number 50887
# testcase number 50888
# testcase number 50889
# testcase number 50890
# testcase number 50891
# testcase number 50892
# testcase number 50893
# testcase number 50894
# testcase number 50895
# testcase number 50896
# testcase number 50897
# testcase number 50898
# testcase number 50899
# testcase number 50900
# testcase number 50901
# testcase number 50902
# testcase number 50903
# testcase number 50904
# testcase number 50905
# testcase number 50906
# testcase number 50907
# testcase number 50908
# testcase number 50909
# testcase number 50910
# testcase number 50911
# testcase number 50912
# testcase number 50913
# testcase number 50914
# testcase number 50915
# testcase number 50916
# testcase number 50917
# testcase number 50918
# testcase number 50919
# testcase number 50920
# testcase number 50921
# testcase number 50922
# testcase number 50923
# testcase number 50924
# testcase number 50925
# testcase number 50926
# testcase number 50927
# testcase number 50928
# testcase number 50929
# testcase number 50930
# testcase number 50931
# testcase number 50932
# testcase number 50933
# testcase number 50934
# testcase number 50935
# testcase number 50936
# testcase number 50937
# testcase number 50938
# testcase number 50939
# testcase number 50940
# testcase number 50941
# testcase number 50942
# testcase number 50943
# testcase number 50944
# testcase number 50945
# testcase number 50946
# testcase number 50947
# testcase number 50948
# testcase number 50949
# testcase number 50950
# testcase number 50951
# testcase number 50952
# testcase number 50953
# testcase number 50954
# testcase number 50955
# testcase number 50956
# testcase number 50957
# testcase number 50958
# testcase number 50959
# testcase number 50960
# testcase number 50961
# testcase number 50962
# testcase number 50963
# testcase number 50964
# testcase number 50965
# testcase number 50966
# testcase number 50967
# testcase number 50968
# testcase number 50969
# testcase number 50970
# testcase number 50971
# testcase number 50972
# testcase number 50973
# testcase number 50974
# testcase number 50975
# testcase number 50976
# testcase number 50977
# testcase number 50978
# testcase number 50979
# testcase number 50980
# testcase number 50981
# testcase number 50982
# testcase number 50983
# testcase number 50984
# testcase number 50985
# testcase number 50986
# testcase number 50987
# testcase number 50988
# testcase number 50989
# testcase number 50990
# testcase number 50991
# testcase number 50992
# testcase number 50993
# testcase number 50994
# testcase number 50995
# testcase number 50996
# testcase number 50997
# testcase number 50998
# testcase number 50999
# testcase number 51000
# testcase number 51001
# testcase number 51002
# testcase number 51003
# testcase number 51004
# testcase number 51005
# testcase number 51006
# testcase number 51007
# testcase number 51008
# testcase number 51009
# testcase number 51010
# testcase number 51011
# testcase number 51012
# testcase number 51013
# testcase number 51014
# testcase number 51015
# testcase number 51016
# testcase number 51017
# testcase number 51018
# testcase number 51019
# testcase number 51020
# testcase number 51021
# testcase number 51022
# testcase number 51023
# testcase number 51024
# testcase number 51025
# testcase number 51026
# testcase number 51027
# testcase number 51028
# testcase number 51029
# testcase number 51030
# testcase number 51031
# testcase number 51032
# testcase number 51033
# testcase number 51034
# testcase number 51035
# testcase number 51036
# testcase number 51037
# testcase number 51038
# testcase number 51039
# testcase number 51040
# testcase number 51041
# testcase number 51042
# testcase number 51043
# testcase number 51044
# testcase number 51045
# testcase number 51046
# testcase number 51047
# testcase number 51048
# testcase number 51049
# testcase number 51050
# testcase number 51051
# testcase number 51052
# testcase number 51053
# testcase number 51054
# testcase number 51055
# testcase number 51056
# testcase number 51057
# testcase number 51058
# testcase number 51059
# testcase number 51060
# testcase number 51061
# testcase number 51062
# testcase number 51063
# testcase number 51064
# testcase number 51065
# testcase number 51066
# testcase number 51067
# testcase number 51068
# testcase number 51069
# testcase number 51070
# testcase number 51071
# testcase number 51072
# testcase number 51073
# testcase number 51074
# testcase number 51075
# testcase number 51076
# testcase number 51077
# testcase number 51078
# testcase number 51079
# testcase number 51080
# testcase number 51081
# testcase number 51082
# testcase number 51083
# testcase number 51084
# testcase number 51085
# testcase number 51086
# testcase number 51087
# testcase number 51088
# testcase number 51089
# testcase number 51090
# testcase number 51091
# testcase number 51092
# testcase number 51093
# testcase number 51094
# testcase number 51095
# testcase number 51096
# testcase number 51097
# testcase number 51098
# testcase number 51099
# testcase number 51100
# testcase number 51101
# testcase number 51102
# testcase number 51103
# testcase number 51104
# testcase number 51105
# testcase number 51106
# testcase number 51107
# testcase number 51108
# testcase number 51109
# testcase number 51110
# testcase number 51111
# testcase number 51112
# testcase number 51113
# testcase number 51114
# testcase number 51115
# testcase number 51116
# testcase number 51117
# testcase number 51118
# testcase number 51119
# testcase number 51120
# testcase number 51121
# testcase number 51122
# testcase number 51123
# testcase number 51124
# testcase number 51125
# testcase number 51126
# testcase number 51127
# testcase number 51128
# testcase number 51129
# testcase number 51130
# testcase number 51131
# testcase number 51132
# testcase number 51133
# testcase number 51134
# testcase number 51135
# testcase number 51136
# testcase number 51137
# testcase number 51138
# testcase number 51139
# testcase number 51140
# testcase number 51141
# testcase number 51142
# testcase number 51143
# testcase number 51144
# testcase number 51145
# testcase number 51146
# testcase number 51147
# testcase number 51148
# testcase number 51149
# testcase number 51150
# testcase number 51151
# testcase number 51152
# testcase number 51153
# testcase number 51154
# testcase number 51155
# testcase number 51156
# testcase number 51157
# testcase number 51158
# testcase number 51159
# testcase number 51160
# testcase number 51161
# testcase number 51162
# testcase number 51163
# testcase number 51164
# testcase number 51165
# testcase number 51166
# testcase number 51167
# testcase number 51168
# testcase number 51169
# testcase number 51170
# testcase number 51171
# testcase number 51172
# testcase number 51173
# testcase number 51174
# testcase number 51175
# testcase number 51176
# testcase number 51177
# testcase number 51178
# testcase number 51179
# testcase number 51180
# testcase number 51181
# testcase number 51182
# testcase number 51183
# testcase number 51184
# testcase number 51185
# testcase number 51186
# testcase number 51187
# testcase number 51188
# testcase number 51189
# testcase number 51190
# testcase number 51191
# testcase number 51192
# testcase number 51193
# testcase number 51194
# testcase number 51195
# testcase number 51196
# testcase number 51197
# testcase number 51198
# testcase number 51199
# testcase number 51200
# testcase number 51201
# testcase number 51202
# testcase number 51203
# testcase number 51204
# testcase number 51205
# testcase number 51206
# testcase number 51207
# testcase number 51208
# testcase number 51209
# testcase number 51210
# testcase number 51211
# testcase number 51212
# testcase number 51213
# testcase number 51214
# testcase number 51215
# testcase number 51216
# testcase number 51217
# testcase number 51218
# testcase number 51219
# testcase number 51220
# testcase number 51221
# testcase number 51222
# testcase number 51223
# testcase number 51224
# testcase number 51225
# testcase number 51226
# testcase number 51227
# testcase number 51228
# testcase number 51229
# testcase number 51230
# testcase number 51231
# testcase number 51232
# testcase number 51233
# testcase number 51234
# testcase number 51235
# testcase number 51236
# testcase number 51237
# testcase number 51238
# testcase number 51239
# testcase number 51240
# testcase number 51241
# testcase number 51242
# testcase number 51243
# testcase number 51244
# testcase number 51245
# testcase number 51246
# testcase number 51247
# testcase number 51248
# testcase number 51249
# testcase number 51250
# testcase number 51251
# testcase number 51252
# testcase number 51253
# testcase number 51254
# testcase number 51255
# testcase number 51256
# testcase number 51257
# testcase number 51258
# testcase number 51259
# testcase number 51260
# testcase number 51261
# testcase number 51262
# testcase number 51263
# testcase number 51264
# testcase number 51265
# testcase number 51266
# testcase number 51267
# testcase number 51268
# testcase number 51269
# testcase number 51270
# testcase number 51271
# testcase number 51272
# testcase number 51273
# testcase number 51274
# testcase number 51275
# testcase number 51276
# testcase number 51277
# testcase number 51278
# testcase number 51279
# testcase number 51280
# testcase number 51281
# testcase number 51282
# testcase number 51283
# testcase number 51284
# testcase number 51285
# testcase number 51286
# testcase number 51287
# testcase number 51288
# testcase number 51289
# testcase number 51290
# testcase number 51291
# testcase number 51292
# testcase number 51293
# testcase number 51294
# testcase number 51295
# testcase number 51296
# testcase number 51297
# testcase number 51298
# testcase number 51299
# testcase number 51300
# testcase number 51301
# testcase number 51302
# testcase number 51303
# testcase number 51304
# testcase number 51305
# testcase number 51306
# testcase number 51307
# testcase number 51308
# testcase number 51309
# testcase number 51310
# testcase number 51311
# testcase number 51312
# testcase number 51313
# testcase number 51314
# testcase number 51315
# testcase number 51316
# testcase number 51317
# testcase number 51318
# testcase number 51319
# testcase number 51320
# testcase number 51321
# testcase number 51322
# testcase number 51323
# testcase number 51324
# testcase number 51325
# testcase number 51326
# testcase number 51327
# testcase number 51328
# testcase number 51329
# testcase number 51330
# testcase number 51331
# testcase number 51332
# testcase number 51333
# testcase number 51334
# testcase number 51335
# testcase number 51336
# testcase number 51337
# testcase number 51338
# testcase number 51339
# testcase number 51340
# testcase number 51341
# testcase number 51342
# testcase number 51343
# testcase number 51344
# testcase number 51345
# testcase number 51346
# testcase number 51347
# testcase number 51348
# testcase number 51349
# testcase number 51350
# testcase number 51351
# testcase number 51352
# testcase number 51353
# testcase number 51354
# testcase number 51355
# testcase number 51356
# testcase number 51357
# testcase number 51358
# testcase number 51359
# testcase number 51360
# testcase number 51361
# testcase number 51362
# testcase number 51363
# testcase number 51364
# testcase number 51365
# testcase number 51366
# testcase number 51367
# testcase number 51368
# testcase number 51369
# testcase number 51370
# testcase number 51371
# testcase number 51372
# testcase number 51373
# testcase number 51374
# testcase number 51375
# testcase number 51376
# testcase number 51377
# testcase number 51378
# testcase number 51379
# testcase number 51380
# testcase number 51381
# testcase number 51382
# testcase number 51383
# testcase number 51384
# testcase number 51385
# testcase number 51386
# testcase number 51387
# testcase number 51388
# testcase number 51389
# testcase number 51390
# testcase number 51391
# testcase number 51392
# testcase number 51393
# testcase number 51394
# testcase number 51395
# testcase number 51396
# testcase number 51397
# testcase number 51398
# testcase number 51399
# testcase number 51400
# testcase number 51401
# testcase number 51402
# testcase number 51403
# testcase number 51404
# testcase number 51405
# testcase number 51406
# testcase number 51407
# testcase number 51408
# testcase number 51409
# testcase number 51410
# testcase number 51411
# testcase number 51412
# testcase number 51413
# testcase number 51414
# testcase number 51415
# testcase number 51416
# testcase number 51417
# testcase number 51418
# testcase number 51419
# testcase number 51420
# testcase number 51421
# testcase number 51422
# testcase number 51423
# testcase number 51424
# testcase number 51425
# testcase number 51426
# testcase number 51427
# testcase number 51428
# testcase number 51429
# testcase number 51430
# testcase number 51431
# testcase number 51432
# testcase number 51433
# testcase number 51434
# testcase number 51435
# testcase number 51436
# testcase number 51437
# testcase number 51438
# testcase number 51439
# testcase number 51440
# testcase number 51441
# testcase number 51442
# testcase number 51443
# testcase number 51444
# testcase number 51445
# testcase number 51446
# testcase number 51447
# testcase number 51448
# testcase number 51449
# testcase number 51450
# testcase number 51451
# testcase number 51452
# testcase number 51453
# testcase number 51454
# testcase number 51455
# testcase number 51456
# testcase number 51457
# testcase number 51458
# testcase number 51459
# testcase number 51460
# testcase number 51461
# testcase number 51462
# testcase number 51463
# testcase number 51464
# testcase number 51465
# testcase number 51466
# testcase number 51467
# testcase number 51468
# testcase number 51469
# testcase number 51470
# testcase number 51471
# testcase number 51472
# testcase number 51473
# testcase number 51474
# testcase number 51475
# testcase number 51476
# testcase number 51477
# testcase number 51478
# testcase number 51479
# testcase number 51480
# testcase number 51481
# testcase number 51482
# testcase number 51483
# testcase number 51484
# testcase number 51485
# testcase number 51486
# testcase number 51487
# testcase number 51488
# testcase number 51489
# testcase number 51490
# testcase number 51491
# testcase number 51492
# testcase number 51493
# testcase number 51494
# testcase number 51495
# testcase number 51496
# testcase number 51497
# testcase number 51498
# testcase number 51499
# testcase number 51500
# testcase number 51501
# testcase number 51502
# testcase number 51503
# testcase number 51504
# testcase number 51505
# testcase number 51506
# testcase number 51507
# testcase number 51508
# testcase number 51509
# testcase number 51510
# testcase number 51511
# testcase number 51512
# testcase number 51513
# testcase number 51514
# testcase number 51515
# testcase number 51516
# testcase number 51517
# testcase number 51518
# testcase number 51519
# testcase number 51520
# testcase number 51521
# testcase number 51522
# testcase number 51523
# testcase number 51524
# testcase number 51525
# testcase number 51526
# testcase number 51527
# testcase number 51528
# testcase number 51529
# testcase number 51530
# testcase number 51531
# testcase number 51532
# testcase number 51533
# testcase number 51534
# testcase number 51535
# testcase number 51536
# testcase number 51537
# testcase number 51538
# testcase number 51539
# testcase number 51540
# testcase number 51541
# testcase number 51542
# testcase number 51543
# testcase number 51544
# testcase number 51545
# testcase number 51546
# testcase number 51547
# testcase number 51548
# testcase number 51549
# testcase number 51550
# testcase number 51551
# testcase number 51552
# testcase number 51553
# testcase number 51554
# testcase number 51555
# testcase number 51556
# testcase number 51557
# testcase number 51558
# testcase number 51559
# testcase number 51560
# testcase number 51561
# testcase number 51562
# testcase number 51563
# testcase number 51564
# testcase number 51565
# testcase number 51566
# testcase number 51567
# testcase number 51568
# testcase number 51569
# testcase number 51570
# testcase number 51571
# testcase number 51572
# testcase number 51573
# testcase number 51574
# testcase number 51575
# testcase number 51576
# testcase number 51577
# testcase number 51578
# testcase number 51579
# testcase number 51580
# testcase number 51581
# testcase number 51582
# testcase number 51583
# testcase number 51584
# testcase number 51585
# testcase number 51586
# testcase number 51587
# testcase number 51588
# testcase number 51589
# testcase number 51590
# testcase number 51591
# testcase number 51592
# testcase number 51593
# testcase number 51594
# testcase number 51595
# testcase number 51596
# testcase number 51597
# testcase number 51598
# testcase number 51599
# testcase number 51600
# testcase number 51601
# testcase number 51602
# testcase number 51603
# testcase number 51604
# testcase number 51605
# testcase number 51606
# testcase number 51607
# testcase number 51608
# testcase number 51609
# testcase number 51610
# testcase number 51611
# testcase number 51612
# testcase number 51613
# testcase number 51614
# testcase number 51615
# testcase number 51616
# testcase number 51617
# testcase number 51618
# testcase number 51619
# testcase number 51620
# testcase number 51621
# testcase number 51622
# testcase number 51623
# testcase number 51624
# testcase number 51625
# testcase number 51626
# testcase number 51627
# testcase number 51628
# testcase number 51629
# testcase number 51630
# testcase number 51631
# testcase number 51632
# testcase number 51633
# testcase number 51634
# testcase number 51635
# testcase number 51636
# testcase number 51637
# testcase number 51638
# testcase number 51639
# testcase number 51640
# testcase number 51641
# testcase number 51642
# testcase number 51643
# testcase number 51644
# testcase number 51645
# testcase number 51646
# testcase number 51647
# testcase number 51648
# testcase number 51649
# testcase number 51650
# testcase number 51651
# testcase number 51652
# testcase number 51653
# testcase number 51654
# testcase number 51655
# testcase number 51656
# testcase number 51657
# testcase number 51658
# testcase number 51659
# testcase number 51660
# testcase number 51661
# testcase number 51662
# testcase number 51663
# testcase number 51664
# testcase number 51665
# testcase number 51666
# testcase number 51667
# testcase number 51668
# testcase number 51669
# testcase number 51670
# testcase number 51671
# testcase number 51672
# testcase number 51673
# testcase number 51674
# testcase number 51675
# testcase number 51676
# testcase number 51677
# testcase number 51678
# testcase number 51679
# testcase number 51680
# testcase number 51681
# testcase number 51682
# testcase number 51683
# testcase number 51684
# testcase number 51685
# testcase number 51686
# testcase number 51687
# testcase number 51688
# testcase number 51689
# testcase number 51690
# testcase number 51691
# testcase number 51692
# testcase number 51693
# testcase number 51694
# testcase number 51695
# testcase number 51696
# testcase number 51697
# testcase number 51698
# testcase number 51699
# testcase number 51700
# testcase number 51701
# testcase number 51702
# testcase number 51703
# testcase number 51704
# testcase number 51705
# testcase number 51706
# testcase number 51707
# testcase number 51708
# testcase number 51709
# testcase number 51710
# testcase number 51711
# testcase number 51712
# testcase number 51713
# testcase number 51714
# testcase number 51715
# testcase number 51716
# testcase number 51717
# testcase number 51718
# testcase number 51719
# testcase number 51720
# testcase number 51721
# testcase number 51722
# testcase number 51723
# testcase number 51724
# testcase number 51725
# testcase number 51726
# testcase number 51727
# testcase number 51728
# testcase number 51729
# testcase number 51730
# testcase number 51731
# testcase number 51732
# testcase number 51733
# testcase number 51734
# testcase number 51735
# testcase number 51736
# testcase number 51737
# testcase number 51738
# testcase number 51739
# testcase number 51740
# testcase number 51741
# testcase number 51742
# testcase number 51743
# testcase number 51744
# testcase number 51745
# testcase number 51746
# testcase number 51747
# testcase number 51748
# testcase number 51749
# testcase number 51750
# testcase number 51751
# testcase number 51752
# testcase number 51753
# testcase number 51754
# testcase number 51755
# testcase number 51756
# testcase number 51757
# testcase number 51758
# testcase number 51759
# testcase number 51760
# testcase number 51761
# testcase number 51762
# testcase number 51763
# testcase number 51764
# testcase number 51765
# testcase number 51766
# testcase number 51767
# testcase number 51768
# testcase number 51769
# testcase number 51770
# testcase number 51771
# testcase number 51772
# testcase number 51773
# testcase number 51774
# testcase number 51775
# testcase number 51776
# testcase number 51777
# testcase number 51778
# testcase number 51779
# testcase number 51780
# testcase number 51781
# testcase number 51782
# testcase number 51783
# testcase number 51784
# testcase number 51785
# testcase number 51786
# testcase number 51787
# testcase number 51788
# testcase number 51789
# testcase number 51790
# testcase number 51791
# testcase number 51792
# testcase number 51793
# testcase number 51794
# testcase number 51795
# testcase number 51796
# testcase number 51797
# testcase number 51798
# testcase number 51799
# testcase number 51800
# testcase number 51801
# testcase number 51802
# testcase number 51803
# testcase number 51804
# testcase number 51805
# testcase number 51806
# testcase number 51807
# testcase number 51808
# testcase number 51809
# testcase number 51810
# testcase number 51811
# testcase number 51812
# testcase number 51813
# testcase number 51814
# testcase number 51815
# testcase number 51816
# testcase number 51817
# testcase number 51818
# testcase number 51819
# testcase number 51820
# testcase number 51821
# testcase number 51822
# testcase number 51823
# testcase number 51824
# testcase number 51825
# testcase number 51826
# testcase number 51827
# testcase number 51828
# testcase number 51829
# testcase number 51830
# testcase number 51831
# testcase number 51832
# testcase number 51833
# testcase number 51834
# testcase number 51835
# testcase number 51836
# testcase number 51837
# testcase number 51838
# testcase number 51839
# testcase number 51840
# testcase number 51841
# testcase number 51842
# testcase number 51843
# testcase number 51844
# testcase number 51845
# testcase number 51846
# testcase number 51847
# testcase number 51848
# testcase number 51849
# testcase number 51850
# testcase number 51851
# testcase number 51852
# testcase number 51853
# testcase number 51854
# testcase number 51855
# testcase number 51856
# testcase number 51857
# testcase number 51858
# testcase number 51859
# testcase number 51860
# testcase number 51861
# testcase number 51862
# testcase number 51863
# testcase number 51864
# testcase number 51865
# testcase number 51866
# testcase number 51867
# testcase number 51868
# testcase number 51869
# testcase number 51870
# testcase number 51871
# testcase number 51872
# testcase number 51873
# testcase number 51874
# testcase number 51875
# testcase number 51876
# testcase number 51877
# testcase number 51878
# testcase number 51879
# testcase number 51880
# testcase number 51881
# testcase number 51882
# testcase number 51883
# testcase number 51884
# testcase number 51885
# testcase number 51886
# testcase number 51887
# testcase number 51888
# testcase number 51889
# testcase number 51890
# testcase number 51891
# testcase number 51892
# testcase number 51893
# testcase number 51894
# testcase number 51895
# testcase number 51896
# testcase number 51897
# testcase number 51898
# testcase number 51899
# testcase number 51900
# testcase number 51901
# testcase number 51902
# testcase number 51903
# testcase number 51904
# testcase number 51905
# testcase number 51906
# testcase number 51907
# testcase number 51908
# testcase number 51909
# testcase number 51910
# testcase number 51911
# testcase number 51912
# testcase number 51913
# testcase number 51914
# testcase number 51915
# testcase number 51916
# testcase number 51917
# testcase number 51918
# testcase number 51919
# testcase number 51920
# testcase number 51921
# testcase number 51922
# testcase number 51923
# testcase number 51924
# testcase number 51925
# testcase number 51926
# testcase number 51927
# testcase number 51928
# testcase number 51929
# testcase number 51930
# testcase number 51931
# testcase number 51932
# testcase number 51933
# testcase number 51934
# testcase number 51935
# testcase number 51936
# testcase number 51937
# testcase number 51938
# testcase number 51939
# testcase number 51940
# testcase number 51941
# testcase number 51942
# testcase number 51943
# testcase number 51944
# testcase number 51945
# testcase number 51946
# testcase number 51947
# testcase number 51948
# testcase number 51949
# testcase number 51950
# testcase number 51951
# testcase number 51952
# testcase number 51953
# testcase number 51954
# testcase number 51955
# testcase number 51956
# testcase number 51957
# testcase number 51958
# testcase number 51959
# testcase number 51960
# testcase number 51961
# testcase number 51962
# testcase number 51963
# testcase number 51964
# testcase number 51965
# testcase number 51966
# testcase number 51967
# testcase number 51968
# testcase number 51969
# testcase number 51970
# testcase number 51971
# testcase number 51972
# testcase number 51973
# testcase number 51974
# testcase number 51975
# testcase number 51976
# testcase number 51977
# testcase number 51978
# testcase number 51979
# testcase number 51980
# testcase number 51981
# testcase number 51982
# testcase number 51983
# testcase number 51984
# testcase number 51985
# testcase number 51986
# testcase number 51987
# testcase number 51988
# testcase number 51989
# testcase number 51990
# testcase number 51991
# testcase number 51992
# testcase number 51993
# testcase number 51994
# testcase number 51995
# testcase number 51996
# testcase number 51997
# testcase number 51998
# testcase number 51999
# testcase number 52000
# testcase number 52001
# testcase number 52002
# testcase number 52003
# testcase number 52004
# testcase number 52005
# testcase number 52006
# testcase number 52007
# testcase number 52008
# testcase number 52009
# testcase number 52010
# testcase number 52011
# testcase number 52012
# testcase number 52013
# testcase number 52014
# testcase number 52015
# testcase number 52016
# testcase number 52017
# testcase number 52018
# testcase number 52019
# testcase number 52020
# testcase number 52021
# testcase number 52022
# testcase number 52023
# testcase number 52024
# testcase number 52025
# testcase number 52026
# testcase number 52027
# testcase number 52028
# testcase number 52029
# testcase number 52030
# testcase number 52031
# testcase number 52032
# testcase number 52033
# testcase number 52034
# testcase number 52035
# testcase number 52036
# testcase number 52037
# testcase number 52038
# testcase number 52039
# testcase number 52040
# testcase number 52041
# testcase number 52042
# testcase number 52043
# testcase number 52044
# testcase number 52045
# testcase number 52046
# testcase number 52047
# testcase number 52048
# testcase number 52049
# testcase number 52050
# testcase number 52051
# testcase number 52052
# testcase number 52053
# testcase number 52054
# testcase number 52055
# testcase number 52056
# testcase number 52057
# testcase number 52058
# testcase number 52059
# testcase number 52060
# testcase number 52061
# testcase number 52062
# testcase number 52063
# testcase number 52064
# testcase number 52065
# testcase number 52066
# testcase number 52067
# testcase number 52068
# testcase number 52069
# testcase number 52070
# testcase number 52071
# testcase number 52072
# testcase number 52073
# testcase number 52074
# testcase number 52075
# testcase number 52076
# testcase number 52077
# testcase number 52078
# testcase number 52079
# testcase number 52080
# testcase number 52081
# testcase number 52082
# testcase number 52083
# testcase number 52084
# testcase number 52085
# testcase number 52086
# testcase number 52087
# testcase number 52088
# testcase number 52089
# testcase number 52090
# testcase number 52091
# testcase number 52092
# testcase number 52093
# testcase number 52094
# testcase number 52095
# testcase number 52096
# testcase number 52097
# testcase number 52098
# testcase number 52099
# testcase number 52100
# testcase number 52101
# testcase number 52102
# testcase number 52103
# testcase number 52104
# testcase number 52105
# testcase number 52106
# testcase number 52107
# testcase number 52108
# testcase number 52109
# testcase number 52110
# testcase number 52111
# testcase number 52112
# testcase number 52113
# testcase number 52114
# testcase number 52115
# testcase number 52116
# testcase number 52117
# testcase number 52118
# testcase number 52119
# testcase number 52120
# testcase number 52121
# testcase number 52122
# testcase number 52123
# testcase number 52124
# testcase number 52125
# testcase number 52126
# testcase number 52127
# testcase number 52128
# testcase number 52129
# testcase number 52130
# testcase number 52131
# testcase number 52132
# testcase number 52133
# testcase number 52134
# testcase number 52135
# testcase number 52136
# testcase number 52137
# testcase number 52138
# testcase number 52139
# testcase number 52140
# testcase number 52141
# testcase number 52142
# testcase number 52143
# testcase number 52144
# testcase number 52145
# testcase number 52146
# testcase number 52147
# testcase number 52148
# testcase number 52149
# testcase number 52150
# testcase number 52151
# testcase number 52152
# testcase number 52153
# testcase number 52154
# testcase number 52155
# testcase number 52156
# testcase number 52157
# testcase number 52158
# testcase number 52159
# testcase number 52160
# testcase number 52161
# testcase number 52162
# testcase number 52163
# testcase number 52164
# testcase number 52165
# testcase number 52166
# testcase number 52167
# testcase number 52168
# testcase number 52169
# testcase number 52170
# testcase number 52171
# testcase number 52172
# testcase number 52173
# testcase number 52174
# testcase number 52175
# testcase number 52176
# testcase number 52177
# testcase number 52178
# testcase number 52179
# testcase number 52180
# ...
# testcase number 52850
# testcase number 52851
# testcase number 52852
# testcase number 52853
# testcase number 52854
# testcase number 52855
# testcase number 52856
# testcase number 52857
# testcase number 52858
# testcase number 52859
# testcase number 52860
# testcase number 52861
# testcase number 52862
# testcase number 52863
# testcase number 52864
# testcase number 52865
# testcase number 52866
# testcase number 52867
# testcase number 52868
# testcase number 52869
# testcase number 52870
# testcase number 52871
# testcase number 52872
# testcase number 52873
# testcase number 52874
# testcase number 52875
# testcase number 52876
# testcase number 52877
# testcase number 52878
# testcase number 52879
# testcase number 52880
# testcase number 52881
# testcase number 52882
# testcase number 52883
# testcase number 52884
# testcase number 52885
# testcase number 52886
# testcase number 52887
# testcase number 52888
# testcase number 52889
# testcase number 52890
# testcase number 52891
# testcase number 52892
# testcase number 52893
# testcase number 52894
# testcase number 52895
# testcase number 52896
# testcase number 52897
# testcase number 52898
# testcase number 52899
# testcase number 52900
# testcase number 52901
# testcase number 52902
# testcase number 52903
# testcase number 52904
# testcase number 52905
# testcase number 52906
# testcase number 52907
# testcase number 52908
# testcase number 52909
# testcase number 52910
# testcase number 52911
# testcase number 52912
# testcase number 52913
# testcase number 52914
# testcase number 52915
# testcase number 52916
# testcase number 52917
# testcase number 52918
# testcase number 52919
# testcase number 52920
# testcase number 52921
# testcase number 52922
# testcase number 52923
# testcase number 52924
# testcase number 52925
# testcase number 52926
# testcase number 52927
# testcase number 52928
# testcase number 52929
# testcase number 52930
# testcase number 52931
# testcase number 52932
# testcase number 52933
# testcase number 52934
# testcase number 52935
# testcase number 52936
# testcase number 52937
# testcase number 52938
# testcase number 52939
# testcase number 52940
# testcase number 52941
# testcase number 52942
# testcase number 52943
# testcase number 52944
# testcase number 52945
# testcase number 52946
# testcase number 52947
# testcase number 52948
# testcase number 52949
# testcase number 52950
# testcase number 52951
# testcase number 52952
# testcase number 52953
# testcase number 52954
# testcase number 52955
# testcase number 52956
# testcase number 52957
# testcase number 52958
# testcase number 52959
# testcase number 52960
# testcase number 52961
# testcase number 52962
# testcase number 52963
# testcase number 52964
# testcase number 52965
# testcase number 52966
# testcase number 52967
# testcase number 52968
# testcase number 52969
# testcase number 52970
# testcase number 52971
# testcase number 52972
# testcase number 52973
# testcase number 52974
# testcase number 52975
# testcase number 52976
# testcase number 52977
# testcase number 52978
# testcase number 52979
# testcase number 52980
# testcase number 52981
# testcase number 52982
# testcase number 52983
# testcase number 52984
# testcase number 52985
# testcase number 52986
# testcase number 52987
# testcase number 52988
# testcase number 52989
# testcase number 52990
# testcase number 52991
# testcase number 52992
# testcase number 52993
# testcase number 52994
# testcase number 52995
# testcase number 52996
# testcase number 52997
# testcase number 52998
# testcase number 52999
# testcase number 53000
# testcase number 53001
# testcase number 53002
# testcase number 53003
# testcase number 53004
# testcase number 53005
# testcase number 53006
# testcase number 53007
# testcase number 53008
# testcase number 53009
# testcase number 53010
# testcase number 53011
# testcase number 53012
# testcase number 53013
# testcase number 53014
# testcase number 53015
# testcase number 53016
# testcase number 53017
# testcase number 53018
# testcase number 53019
# testcase number 53020
# testcase number 53021
# testcase number 53022
# testcase number 53023
# testcase number 53024
# testcase number 53025
# testcase number 53026
# testcase number 53027
# testcase number 53028
# testcase number 53029
# testcase number 53030
# testcase number 53031
# testcase number 53032
# testcase number 53033
# testcase number 53034
# testcase number 53035
# testcase number 53036
# testcase number 53037
# testcase number 53038
# testcase number 53039
# testcase number 53040
# testcase number 53041
# testcase number 53042
# testcase number 53043
# testcase number 53044
# testcase number 53045
# testcase number 53046
# testcase number 53047
# testcase number 53048
# testcase number 53049
# testcase number 53050
# testcase number 53051
# testcase number 53052
# testcase number 53053
# testcase number 53054
# testcase number 53055
# testcase number 53056
# testcase number 53057
# testcase number 53058
# testcase number 53059
# testcase number 53060
# testcase number 53061
# testcase number 53062
# testcase number 53063
# testcase number 53064
# testcase number 53065
# testcase number 53066
# testcase number 53067
# testcase number 53068
# testcase number 53069
# testcase number 53070
# testcase number 53071
# testcase number 53072
# testcase number 53073
# testcase number 53074
# testcase number 53075
# testcase number 53076
# testcase number 53077
# testcase number 53078
# testcase number 53079
# testcase number 53080
# testcase number 53081
# testcase number 53082
# testcase number 53083
# testcase number 53084
# testcase number 53085
# testcase number 53086
# testcase number 53087
# testcase number 53088
# testcase number 53089
# testcase number 53090
# testcase number 53091
# testcase number 53092
# testcase number 53093
# testcase number 53094
# testcase number 53095
# testcase number 53096
# testcase number 53097
# testcase number 53098
# testcase number 53099
# testcase number 53100
# testcase number 53101
# testcase number 53102
# testcase number 53103
# testcase number 53104
# testcase number 53105
# testcase number 53106
# testcase number 53107
# testcase number 53108
# testcase number 53109
# testcase number 53110
# testcase number 53111
# testcase number 53112
# testcase number 53113
# testcase number 53114
# testcase number 53115
# testcase number 53116
# testcase number 53117
# testcase number 53118
# testcase number 53119
# testcase number 53120
# testcase number 53121
# testcase number 53122
# testcase number 53123
# testcase number 53124
# testcase number 53125
# testcase number 53126
# testcase number 53127
# testcase number 53128
# testcase number 53129
# testcase number 53130
# testcase number 53131
# testcase number 53132
# testcase number 53133
# testcase number 53134
# testcase number 53135
# testcase number 53136
# testcase number 53137
# testcase number 53138
# testcase number 53139
# testcase number 53140
# testcase number 53141
# testcase number 53142
# testcase number 53143
# testcase number 53144
# testcase number 53145
# testcase number 53146
# testcase number 53147
# testcase number 53148
# testcase number 53149
# testcase number 53150
# testcase number 53151
# testcase number 53152
# testcase number 53153
# testcase number 53154
# testcase number 53155
# testcase number 53156
# testcase number 53157
# testcase number 53158
# testcase number 53159
# testcase number 53160
# testcase number 53161
# testcase number 53162
# testcase number 53163
# testcase number 53164
# testcase number 53165
# testcase number 53166
# testcase number 53167
# testcase number 53168
# testcase number 53169
# testcase number 53170
# testcase number 53171
# testcase number 53172
# testcase number 53173
# testcase number 53174
# testcase number 53175
# testcase number 53176
# testcase number 53177
# testcase number 53178
# testcase number 53179
# testcase number 53180
# testcase number 53181
# testcase number 53182
# testcase number 53183
# testcase number 53184
# testcase number 53185
# testcase number 53186
# testcase number 53187
# testcase number 53188
# testcase number 53189
# testcase number 53190
# testcase number 53191
# testcase number 53192
# testcase number 53193
# testcase number 53194
# testcase number 53195
# testcase number 53196
# testcase number 53197
# testcase number 53198
# testcase number 53199
# testcase number 53200
# testcase number 53201
# testcase number 53202
# testcase number 53203
# testcase number 53204
# testcase number 53205
# testcase number 53206
# testcase number 53207
# testcase number 53208
# testcase number 53209
# testcase number 53210
# testcase number 53211
# testcase number 53212
# testcase number 53213
# testcase number 53214
# testcase number 53215
# testcase number 53216
# testcase number 53217
# testcase number 53218
# testcase number 53219
# testcase number 53220
# testcase number 53221
# testcase number 53222
# testcase number 53223
# testcase number 53224
# testcase number 53225
# testcase number 53226
# testcase number 53227
# testcase number 53228
# testcase number 53229
# testcase number 53230
# testcase number 53231
# testcase number 53232
# testcase number 53233
# testcase number 53234
# testcase number 53235
# testcase number 53236
# testcase number 53237
# testcase number 53238
# testcase number 53239
# testcase number 53240
# testcase number 53241
# testcase number 53242
# testcase number 53243
# testcase number 53244
# testcase number 53245
# testcase number 53246
# testcase number 53247
# testcase number 53248
# testcase number 53249
# testcase number 53250
# testcase number 53251
# testcase number 53252
# testcase number 53253
# testcase number 53254
# testcase number 53255
# testcase number 53256
# testcase number 53257
# testcase number 53258
# testcase number 53259
# testcase number 53260
# testcase number 53261
# testcase number 53262
# testcase number 53263
# testcase number 53264
# testcase number 53265
# testcase number 53266
# testcase number 53267
# testcase number 53268
# testcase number 53269
# testcase number 53270
# testcase number 53271
# testcase number 53272
# testcase number 53273
# testcase number 53274
# testcase number 53275
# testcase number 53276
# testcase number 53277
# testcase number 53278
# testcase number 53279
# testcase number 53280
# testcase number 53281
# testcase number 53282
# testcase number 53283
# testcase number 53284
# testcase number 53285
# testcase number 53286
# testcase number 53287
# testcase number 53288
# testcase number 53289
# testcase number 53290
# testcase number 53291
# testcase number 53292
# testcase number 53293
# testcase number 53294
# testcase number 53295
# testcase number 53296
# testcase number 53297
# testcase number 53298
# testcase number 53299
# testcase number 53300
# testcase number 53301
# testcase number 53302
# testcase number 53303
# testcase number 53304
# testcase number 53305
# testcase number 53306
# testcase number 53307
# testcase number 53308
# testcase number 53309
# testcase number 53310
# testcase number 53311
# testcase number 53312
# testcase number 53313
# testcase number 53314
# testcase number 53315
# testcase number 53316
# testcase number 53317
# testcase number 53318
# testcase number 53319
# testcase number 53320
# testcase number 53321
# testcase number 53322
# testcase number 53323
# testcase number 53324
# testcase number 53325
# testcase number 53326
# testcase number 53327
# testcase number 53328
# testcase number 53329
# testcase number 53330
# testcase number 53331
# testcase number 53332
# testcase number 53333
# testcase number 53334
# testcase number 53335
# testcase number 53336
# testcase number 53337
# testcase number 53338
# testcase number 53339
# testcase number 53340
# testcase number 53341
# testcase number 53342
# testcase number 53343
# testcase number 53344
# testcase number 53345
# testcase number 53346
# testcase number 53347
# testcase number 53348
# testcase number 53349
# testcase number 53350
# testcase number 53351
# testcase number 53352
# testcase number 53353
# testcase number 53354
# testcase number 53355
# testcase number 53356
# testcase number 53357
# testcase number 53358
# testcase number 53359
# testcase number 53360
# testcase number 53361
# testcase number 53362
# testcase number 53363
# testcase number 53364
# testcase number 53365
# testcase number 53366
# testcase number 53367
# testcase number 53368
# testcase number 53369
# testcase number 53370
# testcase number 53371
# testcase number 53372
# testcase number 53373
# testcase number 53374
# testcase number 53375
# testcase number 53376
# testcase number 53377
# testcase number 53378
# testcase number 53379
# testcase number 53380
# testcase number 53381
# testcase number 53382
# testcase number 53383
# testcase number 53384
# testcase number 53385
# testcase number 53386
# testcase number 53387
# testcase number 53388
# testcase number 53389
# testcase number 53390
# testcase number 53391
# testcase number 53392
# testcase number 53393
# testcase number 53394
# testcase number 53395
# testcase number 53396
# testcase number 53397
# testcase number 53398
# testcase number 53399
# testcase number 53400
# testcase number 53401
# testcase number 53402
# testcase number 53403
# testcase number 53404
# testcase number 53405
# testcase number 53406
# testcase number 53407
# testcase number 53408
# testcase number 53409
# testcase number 53410
# testcase number 53411
# testcase number 53412
# testcase number 53413
# testcase number 53414
# testcase number 53415
# testcase number 53416
# testcase number 53417
# testcase number 53418
# testcase number 53419
# testcase number 53420
# testcase number 53421
# testcase number 53422
# testcase number 53423
# testcase number 53424
# testcase number 53425
# testcase number 53426
# testcase number 53427
# testcase number 53428
# testcase number 53429
# testcase number 53430
# testcase number 53431
# testcase number 53432
# testcase number 53433
# testcase number 53434
# testcase number 53435
# testcase number 53436
# testcase number 53437
# testcase number 53438
# testcase number 53439
# testcase number 53440
# testcase number 53441
# testcase number 53442
# testcase number 53443
# testcase number 53444
# testcase number 53445
# testcase number 53446
# testcase number 53447
# testcase number 53448
# testcase number 53449
# testcase number 53450
# testcase number 53451
# testcase number 53452
# testcase number 53453
# testcase number 53454
# testcase number 53455
# testcase number 53456
# testcase number 53457
# testcase number 53458
# testcase number 53459
# testcase number 53460
# testcase number 53461
# testcase number 53462
# testcase number 53463
# testcase number 53464
# testcase number 53465
# testcase number 53466
# testcase number 53467
# testcase number 53468
# testcase number 53469
# testcase number 53470
# testcase number 53471
# testcase number 53472
# testcase number 53473
# testcase number 53474
# testcase number 53475
# testcase number 53476
# testcase number 53477
# testcase number 53478
# testcase number 53479
# testcase number 53480
# testcase number 53481
# testcase number 53482
# testcase number 53483
# testcase number 53484
# testcase number 53485
# testcase number 53486
# testcase number 53487
# testcase number 53488
# testcase number 53489
# testcase number 53490
# testcase number 53491
# testcase number 53492
# testcase number 53493
# testcase number 53494
# testcase number 53495
# testcase number 53496
# testcase number 53497
# testcase number 53498
# testcase number 53499
# testcase number 53500
# testcase number 53501
# testcase number 53502
# testcase number 53503
# testcase number 53504
# testcase number 53505
# testcase number 53506
# testcase number 53507
# testcase number 53508
# testcase number 53509
# testcase number 53510
# testcase number 53511
# testcase number 53512
# testcase number 53513
# testcase number 53514
# testcase number 53515
# testcase number 53516
# testcase number 53517
# testcase number 53518
# testcase number 53519
# testcase number 53520
# testcase number 53521
# testcase number 53522
# testcase number 53523
# testcase number 53524
# testcase number 53525
# testcase number 53526
# testcase number 53527
# testcase number 53528
# testcase number 53529
# testcase number 53530
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 13
#      11 initial_state = State(loaded_states[i])
#      12 problem = Problem(initial_state, goal_states)
# ---> 13 run_bfs(problem, initial_state, i)
#
# Cell In[23], line 6, in run_bfs(problem, initial_state, testcase_number)
#       4 def run_bfs(problem, initial_state, testcase_number=1):
#       5     bfs = BFS()
# ----> 6     path, expanded_nodes = bfs.BFS(problem)
#       7     if path is None:
#       8         print("No solution found.")
#
# Cell In[22], line 23, in BFS.BFS(self, problem)
#      21 stateOfSuccessor = successor.get_state()
#      22 if stateOfSuccessor not in explored:
# ---> 23     explored.add(stateOfSuccessor)
#      24     successor.set_parent(node)
#      25     frontier.append(successor)
#
# Cell In[15], line 9, in State.__hash__(self)
#       8 def __hash__(self):
# ----> 9     return hash(str(self.board))
#
# KeyboardInterrupt:

# %% [markdown]
# ##Demo

# %%
class Demo:
    def __init__(self, heuristic_choice, mode_choice, numberNodesDraw=None ):
        # heuristic_choice: '1' cho EnhancedManhattan, '2' cho EnhancedMissPlace
        # mode_choice: '1' để chạy mô phỏng có vẽ, '2' để chỉ trả kết quả đánh giá
        if heuristic_choice == '1':
            self.heuristic_type = "EnhancedManhattan"
        elif heuristic_choice == '2':
            self.heuristic_type = "EnhancedMissPlace"
        elif heuristic_choice == '3':
            self.heuristic_type = "PatternDataBase"
        else:
            raise ValueError("Lựa chọn heuristic không hợp lệ. Vui lòng chọn 1 hoặc 2.")

        self.mode_choice = mode_choice

        # Tạo trạng thái ban đầu
        self.initial_state = self.generate_random_state()

        # Thiết lập các trạng thái mục tiêu
        self.goal_states = []
        self.goal_states.append(State([[1, 2, 3], [4, 5, 6], [7, 8, 0]]))
        self.goal_states.append(State([[8, 7, 6], [5, 4, 3], [2, 1, 0]]))
        self.goal_states.append(State([[0, 1, 2], [3, 4, 5], [6, 7, 8]]))
        self.goal_states.append(State([[0, 8, 7], [6, 5, 4], [3, 2, 1]]))

        # Tạo bài toán
        self.problem = Problem(self.initial_state, self.goal_states)

        # Tạo đối tượng tìm kiếm với heuristic đã chọn và số node cần vẽ (nếu có)
        self.search_algo = Search(Heuristic(self.heuristic_type), numberNodesDraw)

    @staticmethod
    def generate_random_state():
        numbers = list(range(9))
        random.seed(42)
        random.shuffle(numbers)
        board = [numbers[i:i+3] for i in range(0, 9, 3)]
        return State(board)

    def run(self):
        if self.mode_choice == '1':
            self.run_simulation()
        elif self.mode_choice == '2':
            self.run_evaluation()
        else:
            print("Lựa chọn chế độ không hợp lệ.")

    def run_simulation(self):
        # Chạy tìm kiếm A* và mô phỏng (với đồ thị)
        path, expanded_nodes = self.search_algo.AStar(self.problem)
        print("=== A* Search Simulation ===")
        print("Initial State:", self.initial_state.get_board())
        for i, node in enumerate(path, start=1):
            print(f"Step {i}: {node.get_state().get_board()}")
        print("Total cost:", len(path))
        print("Số node mở rộng:", expanded_nodes)
        # Vẽ đồ thị với số node cần vẽ (giá trị đã thiết lập)
        self.search_algo.Visual(self.search_algo.numberNodesDraw,self.problem)

    def run_evaluation(self):
     # Đánh giá Pattern Database heuristic (nếu được chọn)
        if self.heuristic_type == "PatternDataBase":
            # 1. Build Pattern Database trước khi chạy A*
            self.search_algo.heuristic.pdbList = self.search_algo.heuristic.PatternDataBaseBuildAll(self.problem.get_goal_states())

            # 2. Chạy A* với PDB heuristic
            path_pdb, expanded_pdb = self.search_algo.AStar(self.problem)
            print("Pattern Database Heuristic Search:")
            print("Initial State:", self.initial_state.get_board())
            for i, node in enumerate(path_pdb, start=1):
                h_value = self.search_algo.heuristic.PatternDataBase(node.get_state(), self.problem.get_goal_states()) # Sử dụng hàm PDB heuristic đã build
                print(f"Step {i}: {node.get_state().get_board()}, H_value: {h_value}")
            print("Total cost (Pattern Database):", len(path_pdb))
            print("Số node mở rộng (Pattern Database):", expanded_pdb)
            print("\n-----------------------------\n")
        # Đánh giá A* search
        astar_search = Search(Heuristic(self.heuristic_type))
        path_astar, expanded_astar = astar_search.AStar(self.problem)
        print("A* Search:")
        print("Initial State:", self.initial_state.get_board())
        for i, node in enumerate(path_astar, start=1):
            h_value = Heuristic.EnhancedManhattanWithAGoal(node.get_state(), path_astar[-1].get_state())
            print(f"Step {i}: {node.get_state().get_board()}, H_value: {h_value}")
        print("Total cost (A*):", len(path_astar))
        print("Số node mở rộng (A*):", expanded_astar)
        print("\n-----------------------------\n")
        # Đánh giá BFS search
        bfs_search = BFS()
        path_bfs, expanded_bfs = bfs_search.BFS(self.problem)
        print("BFS Search:")
        print("Initial State:", self.initial_state.get_board())
        for i, node in enumerate(path_bfs, start=1):
            print(f"Step {i}: {node.get_state().get_board()}")
        print("Total cost (BFS):", len(path_bfs))
        print("Số node mở rộng (BFS):", expanded_bfs)

# -------------------------------
# Giao diện chính (Main)
# -------------------------------

def main():

    print("Chọn ví dụ cho Heuristic:")
    print("1: EnhancedManhattan")
    print("2: EnhancedMissPlace")
    print("3: PatternDataBase")
    heuristic_choice = input("Nhập lựa chọn (1, 2 hoặc 3): ").strip()

    print("\nChọn chế độ:")
    print("1: Chạy mô phỏng (có vẽ mô phỏng)")
    print("2: Chỉ trả đánh giá kết quả")
    mode_choice = input("Nhập lựa chọn (1 hoặc 2): ").strip()
    print("Chọn số testcase: ")
    n = input("Nhập số testcase (số nguyên): ").strip()

    numberNodesDraw = 0
    if mode_choice == '1':
        # Yêu cầu người dùng nhập số node muốn vẽ (nếu có)
        try:
            numberNodesDraw = int(input("Nhập số node muốn vẽ (số nguyên): ").strip())
        except ValueError:
            numberNodesDraw = 0

    try:
        for i in range(int(n)):
            print(f"\nTest case {i+1}:")
            demo = Demo(heuristic_choice, mode_choice, numberNodesDraw)
            demo.run()
    except ValueError as e:
        print(e)

if __name__ == "__main__":
    main()
# Out:
# Chọn ví dụ cho Heuristic:
# 1: EnhancedManhattan
# 2: EnhancedMissPlace
# 3: PatternDataBase
#
# Chọn chế độ:
# 1: Chạy mô phỏng (có vẽ mô phỏng)
# 2: Chỉ trả đánh giá kết quả
# Chọn số testcase:
#
# Test case 1:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 2:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 3:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 4:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 5:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 6:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 7:
# Pattern Database Heuristic Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 13
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [2, 4, 0], [5, 8, 1]], H_value: 13
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 1
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (Pattern Database): 14
# Số node mở rộng (Pattern Database): 2959
#
# -----------------------------
#
# A* Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]], H_value: 11
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]], H_value: 12
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]], H_value: 9
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]], H_value: 10
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]], H_value: 9
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]], H_value: 8
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]], H_value: 7
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]], H_value: 6
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]], H_value: 5
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]], H_value: 4
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]], H_value: 3
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]], H_value: 2
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]], H_value: 3
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]], H_value: 0
# Total cost (A*): 14
# Số node mở rộng (A*): 4441
#
# -----------------------------
#
# BFS Search:
# Initial State: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 1: [[3, 6, 7], [4, 8, 2], [5, 0, 1]]
# Step 2: [[3, 6, 7], [4, 0, 2], [5, 8, 1]]
# Step 3: [[3, 6, 7], [0, 2, 4], [5, 8, 1]]
# Step 4: [[3, 6, 7], [2, 0, 4], [5, 8, 1]]
# Step 5: [[3, 6, 7], [2, 8, 4], [5, 0, 1]]
# Step 6: [[3, 6, 7], [2, 8, 4], [0, 5, 1]]
# Step 7: [[3, 6, 7], [0, 8, 4], [2, 5, 1]]
# Step 8: [[0, 6, 7], [3, 8, 4], [2, 5, 1]]
# Step 9: [[6, 0, 7], [3, 8, 4], [2, 5, 1]]
# Step 10: [[6, 8, 7], [3, 0, 4], [2, 5, 1]]
# Step 11: [[6, 8, 7], [3, 5, 4], [2, 0, 1]]
# Step 12: [[6, 8, 7], [3, 5, 4], [0, 2, 1]]
# Step 13: [[6, 8, 7], [0, 5, 4], [3, 2, 1]]
# Step 14: [[0, 8, 7], [6, 5, 4], [3, 2, 1]]
# Total cost (BFS): 14
# Số node mở rộng (BFS): 3742
#
# Test case 8:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 133
#     130         print(e)
#     132 if __name__ == "__main__":
# --> 133     main()
#
# Cell In[13], line 128, in main()
#     126         print(f"\nTest case {i+1}:")
#     127         demo = Demo(heuristic_choice, mode_choice, numberNodesDraw)
# --> 128         demo.run()
#     129 except ValueError as e:
#     130     print(e)
#
# Cell In[13], line 44, in Demo.run(self)
#      42     self.run_simulation()
#      43 elif self.mode_choice == '2':
# ---> 44     self.run_evaluation()
#      45 else:
#      46     print("Lựa chọn chế độ không hợp lệ.")
#
# Cell In[13], line 64, in Demo.run_evaluation(self)
#      60 def run_evaluation(self):
#      61  # Đánh giá Pattern Database heuristic (nếu được chọn)
#      62     if self.heuristic_type == "PatternDataBase":
#      63         # 1. Build Pattern Database trước khi chạy A*
# ---> 64         self.search_algo.heuristic.pdbList = self.search_algo.heuristic.PatternDataBaseBuildAll(self.problem.get_goal_states())
#      66         # 2. Chạy A* với PDB heuristic
#      67         path_pdb, expanded_pdb = self.search_algo.AStar(self.problem)
#
# Cell In[6], line 163, in Heuristic.PatternDataBaseBuildAll(self, goalStates)
#     161 pdb_list = []
#     162 for goal in goalStates:
# --> 163     pdb_g = self.buildPDBFromGoal(goal)
#     164     pdb_list.append(pdb_g)
#     165 return pdb_list
#
# Cell In[6], line 187, in Heuristic.buildPDBFromGoal(self, goal)
#     184 current_cost = pdb[current_cost_key]
#     186 current_node = Node(current_state)
# --> 187 for successor in current_node.getSuccessors():
#     188     succ_key = tuple(num for row in successor.get_state().get_board() for num in row)
#     189     if succ_key not in pdb:
#
# Cell In[5], line 58, in Node.getSuccessors(self)
#      56 state_of_node = self.get_state()
#      57 for action in state_of_node.getActions():
# ---> 58     new_state = state_of_node.getSuccessor(action)
#      59     cost = new_state.getActionCost(state_of_node, action)
#      60     successors.append(Node(new_state, action, self, cost))
#
# Cell In[4], line 52, in State.getSuccessor(self, action)
#      50 def getSuccessor(self, action):
#      51     blank_position = self.get_blank_position()
# ---> 52     new_state = copy.deepcopy(self)
#      54     if 'U' == action:
#      55         new_state.swap(blank_position, (blank_position[0] - 1, blank_position[1]))
#
# File ~/anaconda3/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/anaconda3/lib/python3.12/copy.py:253, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     251 if deep and args:
#     252     args = (deepcopy(arg, memo) for arg in args)
# --> 253 y = func(*args)
#     254 if deep:
#     255     memo[id(x)] = y
#
# File ~/anaconda3/lib/python3.12/copyreg.py:98, in __newobj__(cls, *args)
#      94         return _reconstructor, args
#      96 # Helper for __reduce_ex__ protocol 2
# ---> 98 def __newobj__(cls, *args):
#      99     return cls.__new__(cls, *args)
#     101 def __newobj_ex__(cls, args, kwargs):
#
# KeyboardInterrupt:
